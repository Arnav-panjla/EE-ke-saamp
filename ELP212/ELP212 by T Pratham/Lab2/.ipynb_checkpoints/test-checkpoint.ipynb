# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.transforms as mtransforms

# %%
theta = np.array([np.pi*x/18 for x in range(37)])
h_power = [
    -39.47,
    -33.5,
    -35.5,
    -35,
    -38.5,
    -38.73,
    -38,
    -36.41,
    -32.86,
    -33.16,
    -39.04,
    -36.2,
    -34.7,
    -33.53,
    -30.53,
    -28.04,
    -26.14,
    -25.95,
    -25.72,
    -24.29,
    -25.07,
    -25.52,
    -26.33,
    -28.95,
    -32.5,
    -38.24,
    -30.88,
    -24.31,
    -22.09,
    -24.02,
    -25.54,
    -25.49,
    -27.47,
    -27.24,
    -27.5,
    -27.77,
    -30.33
]

e_power = [
    33.11,
    32.62,
    32.75,
    32.14,
    33.35,
    33.04,
    34.88,
    35.84,
    35.74,
    32.75,
    30.68,
    29.86,
    28.77,
    30.43,
    34.44,
    37.17,
    40.87,
    43.49,
    42.01,
    39.03,
    39.33,
    36.43,
    32.04,
    31.99,
    27.35,
    26.33,
    28.68,
    28.71,
    30.03,
    34.13,
    39.11,
    39.91,
    40.34,
    34.11,
    35.12,
    35.02,
    37.06
]
h_power = np.array(h_power)
e_power = -1*np.array(e_power)

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "polar"})
# ax.set_rmax(100)

# for i in range(len(theta)-1):
    # plt.arrow(np.pi*theta[i]/180, h_power[i], np.pi*(theta[i+1]-theta[i])/180, h_power[i+1]-h_power[i])
ax.plot(theta, h_power)
ax.plot(theta, e_power)
# plt.polar(theta, h_power, 'o')
# plt.polar(theta, e_power)
plt.show()
